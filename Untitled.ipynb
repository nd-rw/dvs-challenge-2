# %%
import pandas as pd
import os
import re
import math
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()
ss = sid.polarity_scores

# %%
def create_emoji_dict():
    """
    Uses a combination of code from two functions from the VaderSentiment.py file
    from the python library Vader to convert emoji lexicon file to a dictionary.
    """
    emoji_full_filepath = 'dvs2_data/emoji_utf8_lexicon.txt'
    with open(emoji_full_filepath, encoding='utf-8') as f:
        emoji_full_filepath = f.read()
    emoji_dict = {}
    for line in emoji_full_filepath.split('\n'):
        (emoji, description) = line.strip().split('\t')[0:2]
        emoji_dict[emoji] = description
    return emoji_dict

# %%
emojis_df = pd.read_csv('dvs2_data/emoji_over_time.csv')
emojis = set(emojis_df['emoji'])
emoji_dict = create_emoji_dict()

# %%
ss('chart with upwards trend')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
slack_to_emoji_lexicon = {'+1': "thumbs up",
                         '100': "one hundred"}

# %%
slack_to_emoji_lexicon = {}

for emoji in emojis:
    key = ''
    value = ''
    key = emoji
    if ':' in emoji:
        print(str(emoji) + ' skipped')
# Out:
# ok_hand::skin-tone-3 skipped
# +1::skin-tone-5 skipped
# +1::skin-tone-3 skipped
# clap::skin-tone-4 skipped
# muscle::skin-tone-3 skipped
# +1::skin-tone-2 skipped
# raised_hands::skin-tone-3 skipped
# point_up_2::skin-tone-3 skipped
# crossed_fingers::skin-tone-3 skipped
# +1::skin-tone-4 skipped
# wave::skin-tone-5 skipped
# wave::skin-tone-2 skipped
# wave::skin-tone-4 skipped
# point_up_2::skin-tone-4 skipped
# raised_hands::skin-tone-4 skipped
# clap::skin-tone-2 skipped
# wave::skin-tone-3 skipped
# ok_hand::skin-tone-2 skipped
# clap::skin-tone-3 skipped
# pray::skin-tone-3 skipped

# %%
emojis
# Out:
# {'+1',
#  '+1::skin-tone-2',
#  '+1::skin-tone-3',
#  '+1::skin-tone-4',
#  '+1::skin-tone-5',
#  '-1',
#  '100',
#  '1234',
#  'abc',
#  'abcd',
#  'airplane',
#  'alembic',
#  'alien',
#  'all_the_things',
#  'ambulance',
#  'anchor',
#  'angel',
#  'anguished',
#  'apple',
#  'archer',
#  'arrow_up',
#  'art',
#  'arthur-dance',
#  'astonished',
#  'aw_yeah',
#  'baby',
#  'bamboo',
#  'banana-dance',
#  'bangbang',
#  'bar_chart',
#  'baseball',
#  'basketball',
#  'beach_with_umbrella',
#  'bear',
#  'bee',
#  'beer',
#  'beers',
#  'bicyclist',
#  'bike',
#  'billed_cap',
#  'biohazard_sign',
#  'black_heart',
#  'blossom',
#  'blue_book',
#  'blue_heart',
#  'blush',
#  'book',
#  'bookmark',
#  'bookmark_tabs',
#  'books',
#  'boom',
#  'bouquet',
#  'bowling',
#  'brain',
#  'bread',
#  'bulb',
#  'butterfly',
#  'calendar',
#  'call_me_hand',
#  'calling',
#  'camera',
#  'camera_with_flash',
#  'candy',
#  'car',
#  'carousel_horse',
#  'cat',
#  'cat2',
#  'chains',
#  'champagne',
#  'chart_with_upwards_trend',
#  'checkered_flag',
#  'cheese_wedge',
#  'cherry_blossom',
#  'chicago',
#  'chipmunk',
#  'chocolate_bar',
#  'city_sunset',
#  'cityscape',
#  'clap',
#  'clap::skin-tone-2',
#  'clap::skin-tone-3',
#  'clap::skin-tone-4',
#  'clapping-all',
#  'clipboard',
#  'clock1',
#  'coffee',
#  'computer',
#  'confetti_ball',
#  'cookie_monster_cat',
#  'cool',
#  'crab_rave',
#  'crescent_moon',
#  'cricket',
#  'cricket_bat_and_ball',
#  'crossed_fingers',
#  'crossed_fingers::skin-tone-3',
#  'crossed_swords',
#  'crown',
#  'cry',
#  'cyclone',
#  'd3',
#  'dancer',
#  'dart',
#  'dash',
#  'data-viz-soc',
#  'de',
#  'deciduous_tree',
#  'desert_island',
#  'diamonds',
#  'dino',
#  'disappointed',
#  'disappointed_relieved',
#  'dizzy',
#  'dizzy_face',
#  'dog',
#  'dog2',
#  'dove_of_peace',
#  'drake-dislike',
#  'drake-like',
#  'drooling_face',
#  'droplet',
#  'drum_with_drumsticks',
#  'dusty_stick',
#  'dvs',
#  'ear',
#  'earth_africa',
#  'earth_americas',
#  'earth_asia',
#  'electric_plug',
#  'elephant',
#  'es',
#  'european_castle',
#  'exclamation',
#  'exploding_head',
#  'eye',
#  'eyes',
#  'face_with_hand_over_mouth',
#  'face_with_monocle',
#  'face_with_raised_eyebrow',
#  'face_with_rolling_eyes',
#  'facepunch',
#  'fairy',
#  'fb-angry',
#  'fb-like',
#  'fb-wow',
#  'female-artist',
#  'female-doctor',
#  'female-student',
#  'female-teacher',
#  'female-technologist',
#  'female_fairy',
#  'female_genie',
#  'female_mage',
#  'female_vampire',
#  'feminism',
#  'fencer',
#  'film_projector',
#  'fire',
#  'fireworks',
#  'first_place_medal',
#  'fist',
#  'five',
#  'flag-aq',
#  'flag-ar',
#  'flag-au',
#  'flag-br',
#  'flag-bv',
#  'flag-ca',
#  'flag-ch',
#  'flag-co',
#  'flag-dk',
#  'flag-eu',
#  'flag-fi',
#  'flag-gl',
#  'flag-ie',
#  'flag-mx',
#  'flag-no',
#  'flag-nz',
#  'flag-ph',
#  'flag-pl',
#  'flag-ro',
#  'flag-sg',
#  'flag-si',
#  'flag-wales',
#  'fleur_de_lis',
#  'floppy_disk',
#  'flower_playing_cards',
#  'flushed',
#  'football',
#  'fountain',
#  'four_leaf_clover',
#  'fr',
#  'frame_with_picture',
#  'fried_egg',
#  'gavel',
#  'gb',
#  'gem',
#  'gestalt-dvs',
#  'gestalt-o',
#  'ggplot2',
#  'gift_heart',
#  'github',
#  'globe_with_meridians',
#  'gloves',
#  'golf',
#  'grapes',
#  'green_heart',
#  'grimacing',
#  'grin',
#  'grinning',
#  'guitar',
#  'gun',
#  'hamburger',
#  'hand',
#  'handshake',
#  'hatched_chick',
#  'hatching_chick',
#  'headphones',
#  'heart',
#  'heart_eyes',
#  'heart_eyes_cat',
#  'heartpulse',
#  'heavy_check_mark',
#  'heavy_dollar_sign',
#  'heavy_heart_exclamation_mark_ornament',
#  'heavy_plus_sign',
#  'helicopter',
#  'horse',
#  'hotdog',
#  'hourglass',
#  'hourglass_flowing_sand',
#  'hugging_face',
#  'hushed',
#  'i_love_you_hand_sign',
#  'ice_hockey_stick_and_puck',
#  'interrobang',
#  'it',
#  'joy',
#  'jp',
#  'kissing',
#  'kiwifruit',
#  'laughing',
#  'left-facing_fist',
#  'leftwards_arrow_with_hook',
#  'lightning',
#  'lion_face',
#  'lollipop',
#  'loud_sound',
#  'loudspeaker',
#  'lying_face',
#  'mahjong',
#  'male-scientist',
#  'male-singer',
#  'male_genie',
#  'male_vampire',
#  'man-biking',
#  'man-cartwheeling',
#  'man-golfing',
#  'man-raising-hand',
#  'man-shrugging',
#  'man_dancing',
#  'maple_leaf',
#  'mario',
#  'mario_luigi_dance',
#  'martial_arts_uniform',
#  'mask',
#  'mega',
#  'memo',
#  'mermaid',
#  'metro',
#  'microphone',
#  'microscope',
#  'milky_way',
#  'mortar_board',
#  'motorway',
#  'mount_fuji',
#  'mountain',
#  'muscle',
#  'muscle::skin-tone-3',
#  'musical_keyboard',
#  'musical_note',
#  'musical_score',
#  'nauseated_face',
#  'nerd_face',
#  'new_moon_with_face',
#  'newspaper',
#  'no_bell',
#  'no_entry_sign',
#  'nod',
#  'ocean',
#  'octopus',
#  'ok_hand',
#  'ok_hand::skin-tone-2',
#  'ok_hand::skin-tone-3',
#  'open_hands',
#  'open_mouth',
#  'orange_book',
#  'package',
#  'packedbars',
#  'panda-dance',
#  'panda_face',
#  'parrot',
#  'partly_sunny_rain',
#  'party-bar-chart',
#  'party-chart-with-downwards-trend',
#  'party-chart-with-upwards-trend',
#  'party-computer',
#  'party-ft',
#  'party-heart',
#  'party-jason-f',
#  'peace_symbol',
#  'pencil2',
#  'penguin',
#  'person_doing_cartwheel',
#  'phrasing',
#  'pie',
#  'pie-chart',
#  'pig_nose',
#  'pineapple',
#  'pizza',
#  'please-consider-threading',
#  'plus1',
#  'point_down',
#  'point_up',
#  'point_up_2',
#  'point_up_2::skin-tone-3',
#  'point_up_2::skin-tone-4',
#  'pokeball',
#  'poodle',
#  'popcorn',
#  'pray',
#  'pray::skin-tone-3',
#  'pretzel',
#  'prince',
#  'purple_heart',
#  'pushpin',
#  'python',
#  'question',
#  'r',
#  'r-lang',
#  'racehorse',
#  'radio',
#  'rage',
#  'rain_cloud',
#  'rainbow',
#  'rainbow_puke',
#  'raised_hand_with_fingers_splayed',
#  'raised_hands',
#  'raised_hands::skin-tone-3',
#  'raised_hands::skin-tone-4',
#  'relaxed',
#  'relieved',
#  'ribbon',
#  'right-facing_fist',
#  'robot_face',
#  'rocket',
#  'rolled_up_newspaper',
#  'rolling_on_the_floor_laughing',
#  'rotating_light',
#  'round_pushpin',
#  'ru',
#  'sandwich',
#  'satellite',
#  'satellite_antenna',
#  'scales',
#  'school',
#  'scream',
#  'scream_cat',
#  'see_no_evil',
#  'seedling',
#  'shark',
#  'sheep',
#  'shield',
#  'ship',
#  'shrimp',
#  'simple_smile',
#  'skier',
#  'slack',
#  'slam',
#  'sleeping',
#  'sleepy',
#  'slightly_frowning_face',
#  'slightly_smiling_face',
#  'smile',
#  'smile_cat',
#  'smiley',
#  'smiley_cat',
#  'smirk',
#  'snake',
#  'snow_capped_mountain',
#  'snowflake',
#  'snowman_without_snow',
#  'sob',
#  'sob_cat',
#  'soccer',
#  'soon',
#  'space_invader',
#  'spaghetti',
#  'sparkler',
#  'sparkles',
#  'sparkling_heart',
#  'speak_no_evil',
#  'speaking_head_in_silhouette',
#  'speech_balloon',
#  'spider_web',
#  'spiral_note_pad',
#  'sports_medal',
#  'spotify',
#  'star',
#  'star-struck',
#  'star2',
#  'star_struck_cat',
#  'starbucks',
#  'statue_of_liberty',
#  'steam_locomotive',
#  'stopwatch',
#  'straight_ruler',
#  'stuck_out_tongue',
#  'stuck_out_tongue_closed_eyes',
#  'stuck_out_tongue_winking_eye',
#  'studio_microphone',
#  'success_kid',
#  'sunglasses',
#  'sunglasses_cat',
#  'sunny',
#  'sweat',
#  'sweat_smile',
#  'swimmer',
#  'syringe',
#  'tableau',
#  'taco',
#  'tada',
#  'tangerine',
#  'tea',
#  'tennis',
#  'thankyou',
#  'the_horns',
#  'thinking',
#  'thinking_face',
#  'thought_balloon',
#  'thumbsup_all',
#  'thunder_cloud_and_rain',
#  'tiger',
#  'tomato',
#  'top',
#  'tophat',
#  'triangular_ruler',
#  'trident',
#  'triumph',
#  'trophy',
#  'turkey',
#  'turtle',
#  'unicorn_face',
#  'upside_down_face',
#  'us',
#  'v',
#  'vertical_traffic_light',
#  'video_camera',
#  'video_game',
#  'visz',
#  'vs',
#  'warning',
#  'watch',
#  'wave',
#  'wave::skin-tone-2',
#  'wave::skin-tone-3',
#  'wave::skin-tone-4',
#  'wave::skin-tone-5',
#  'weary',
#  'white_check_mark',
#  'white_large_square',
#  'white_small_square',
#  'wind_blowing_face',
#  'wine_glass',
#  'wink',
#  'wolf',
#  'woman-gesturing-ok',
#  'woman-lifting-weights',
#  'woman-raising-hand',
#  'woman-shrugging',
#  'woman-surfing',
#  'woman-walking',
#  'woman-with-bunny-ears-partying',
#  'world_map',
#  'writing_hand',
#  'yasss_cat',
#  'yay',
#  'yayy',
#  'yellow_heart',
#  'yum',
#  'zany_face',
#  'zap',
#  'zero'}
